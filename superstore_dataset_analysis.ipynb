# %%
#Load the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset
df=pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State
# 0    Second Class   Consumer  United States        Henderson    Kentucky  \
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity
# 0        42420  South        Furniture    Bookcases  261.9600         2  \
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.drop(columns="Postal Code",inplace=True)

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State
# 0    Second Class   Consumer  United States        Henderson    Kentucky  \
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
print(df["Ship Mode"].unique())
print(df["Segment"].unique())
print(df["Country"].unique())
print(df["Category"].unique())
print(df["Sub-Category"].unique())
print(df["Region"].unique())
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']
# ['Consumer' 'Corporate' 'Home Office']
# ['United States']
# ['Furniture' 'Office Supplies' 'Technology']
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']
# ['South' 'West' 'Central' 'East']

# %% [markdown]
# Statistical Description of the Data

# %%
df.describe(include="all")
# Out:
#              Ship Mode   Segment        Country           City       State
# count             9994      9994           9994           9994        9994  \
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
#        Region         Category Sub-Category         Sales     Quantity
# count    9994             9994         9994   9994.000000  9994.000000  \
# unique      4                3           17           NaN          NaN
# top      West  Office Supplies      Binders           NaN          NaN
# freq     3203             6026         1523           NaN          NaN
# mean      NaN              NaN          NaN    229.858001     3.789574
# std       NaN              NaN          NaN    623.245101     2.225110
# min       NaN              NaN          NaN      0.444000     1.000000
# 25%       NaN              NaN          NaN     17.280000     2.000000
# 50%       NaN              NaN          NaN     54.490000     3.000000
# 75%       NaN              NaN          NaN    209.940000     5.000000
# max       NaN              NaN          NaN  22638.480000    14.000000
#
#            Discount       Profit
# count   9994.000000  9994.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean       0.156203    28.656896
# std        0.206452   234.260108
# min        0.000000 -6599.978000
# 25%        0.000000     1.728750
# 50%        0.200000     8.666500
# 75%        0.200000    29.364000
# max        0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Region        9994 non-null   object
#  6   Category      9994 non-null   object
#  7   Sub-Category  9994 non-null   object
#  8   Sales         9994 non-null   float64
#  9   Quantity      9994 non-null   int64
#  10  Discount      9994 non-null   float64
#  11  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 937.1+ KB

# %% [markdown]
# Data Cleaning

# %%
#to check missing values
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# Duplicate Data

# %%
df.duplicated().sum()
# Out:
# 50

# %%
#Show duplicated rows
df[df.duplicated(keep='last')]
# Out:
#            Ship Mode      Segment        Country           City         State
# 218   Standard Class     Consumer  United States    Los Angeles    California  \
# 568   Standard Class    Corporate  United States        Seattle    Washington
# 591   Standard Class     Consumer  United States          Salem        Oregon
# 845      First Class    Corporate  United States    Los Angeles    California
# 925      First Class     Consumer  United States   Philadelphia  Pennsylvania
# 935   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 1037     First Class     Consumer  United States    Los Angeles    California
# 1103  Standard Class     Consumer  United States        Houston         Texas
# 1143  Standard Class     Consumer  United States    Los Angeles    California
# 1186  Standard Class    Corporate  United States        Seattle    Washington
# 1479  Standard Class     Consumer  United States  San Francisco    California
# 1710  Standard Class     Consumer  United States  San Francisco    California
# 1741  Standard Class     Consumer  United States   Philadelphia  Pennsylvania
# 2044  Standard Class    Corporate  United States        Houston         Texas
# 2128  Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 2198  Standard Class     Consumer  United States   Philadelphia  Pennsylvania
# 2251    Second Class     Consumer  United States    Los Angeles    California
# 2803  Standard Class     Consumer  United States  San Francisco    California
# 2807    Second Class     Consumer  United States        Seattle    Washington
# 2836  Standard Class     Consumer  United States    Los Angeles    California
# 2887     First Class     Consumer  United States    Los Angeles    California
# 3025  Standard Class     Consumer  United States  New York City      New York
# 3127  Standard Class     Consumer  United States  New York City      New York
# 3405  Standard Class  Home Office  United States       Columbus          Ohio
# 3412  Standard Class    Corporate  United States  San Francisco    California
# 3842     First Class    Corporate  United States    Los Angeles    California
# 3940  Standard Class     Consumer  United States  New York City      New York
# 4089  Standard Class    Corporate  United States  New York City      New York
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4311  Standard Class     Consumer  United States    Los Angeles    California
# 4498  Standard Class    Corporate  United States  San Francisco    California
# 5067  Standard Class  Home Office  United States    Los Angeles    California
# 5079  Standard Class     Consumer  United States  San Francisco    California
# 5098  Standard Class     Consumer  United States        Chicago      Illinois
# 5227  Standard Class     Consumer  United States  New York City      New York
# 5299     First Class    Corporate  United States      San Diego    California
# 5329    Second Class     Consumer  United States  New York City      New York
# 5372  Standard Class    Corporate  United States        Houston         Texas
# 5405  Standard Class     Consumer  United States    Los Angeles    California
# 5493        Same Day  Home Office  United States  San Francisco    California
# 5982  Standard Class     Consumer  United States  New York City      New York
# 6245  Standard Class  Home Office  United States        Seattle    Washington
# 6391  Standard Class     Consumer  United States  New York City      New York
# 6409     First Class     Consumer  United States        Houston         Texas
# 6774  Standard Class  Home Office  United States    Los Angeles    California
# 7123  Standard Class    Corporate  United States  New York City      New York
# 7708  Standard Class     Consumer  United States   Philadelphia  Pennsylvania
# 8219  Standard Class     Consumer  United States         Dallas         Texas
# 8457    Second Class    Corporate  United States        Chicago      Illinois
# 8533  Standard Class     Consumer  United States        Detroit      Michigan
#
#        Region         Category Sub-Category    Sales  Quantity  Discount
# 218      West       Technology       Phones  302.376         3      0.20  \
# 568      West  Office Supplies        Paper   19.440         3      0.00
# 591      West  Office Supplies        Paper   10.368         2      0.20
# 845      West  Office Supplies       Labels   14.620         2      0.00
# 925      East  Office Supplies        Paper   15.552         3      0.20
# 935      East  Office Supplies        Paper   15.552         3      0.20
# 1037     West  Office Supplies      Binders   36.624         3      0.20
# 1103  Central  Office Supplies      Binders    2.934         3      0.80
# 1143     West  Office Supplies        Paper    6.480         1      0.00
# 1186     West  Office Supplies        Paper   25.920         4      0.00
# 1479     West  Office Supplies        Paper   25.920         4      0.00
# 1710     West  Office Supplies          Art   19.900         5      0.00
# 1741     East  Office Supplies        Paper   20.736         4      0.20
# 2044  Central  Office Supplies        Paper   15.552         3      0.20
# 2128     East  Office Supplies        Paper   20.736         4      0.20
# 2198     East  Office Supplies        Paper   15.552         3      0.20
# 2251     West  Office Supplies        Paper   19.440         3      0.00
# 2803     West  Office Supplies        Paper   12.840         3      0.00
# 2807     West  Office Supplies        Paper   12.960         2      0.00
# 2836     West  Office Supplies        Paper   19.440         3      0.00
# 2887     West  Office Supplies        Paper   12.960         2      0.00
# 3025     East  Office Supplies        Paper   17.940         3      0.00
# 3127     East  Office Supplies        Paper   49.120         4      0.00
# 3405     East        Furniture       Chairs  281.372         2      0.30
# 3412     West  Office Supplies          Art   11.760         4      0.00
# 3842     West  Office Supplies      Binders    7.184         2      0.20
# 3940     East        Furniture  Furnishings   14.560         2      0.00
# 4089     East  Office Supplies       Labels   20.700         2      0.00
# 4117     West  Office Supplies        Paper   19.440         3      0.00
# 4311     West  Office Supplies        Paper   19.440         3      0.00
# 4498     West  Office Supplies        Paper   12.960         2      0.00
# 5067     West  Office Supplies          Art   21.400         5      0.00
# 5079     West        Furniture    Bookcases  359.499         3      0.15
# 5098  Central  Office Supplies      Storage   35.168         2      0.20
# 5227     East        Furniture    Bookcases  353.568         2      0.20
# 5299     West  Office Supplies       Labels   18.900         3      0.00
# 5329     East  Office Supplies      Binders   33.568         2      0.20
# 5372  Central  Office Supplies        Paper   15.552         3      0.20
# 5405     West       Technology  Accessories   36.240         1      0.00
# 5493     West  Office Supplies       Labels   41.400         4      0.00
# 5982     East  Office Supplies        Paper   12.960         2      0.00
# 6245     West        Furniture  Furnishings   22.140         3      0.00
# 6391     East  Office Supplies        Paper   14.620         2      0.00
# 6409  Central  Office Supplies        Paper   47.952         3      0.20
# 6774     West  Office Supplies        Paper   38.880         6      0.00
# 7123     East        Furniture  Furnishings   10.020         3      0.00
# 7708     East       Technology  Accessories   40.776         3      0.20
# 8219  Central  Office Supplies       Labels    4.928         2      0.20
# 8457  Central  Office Supplies      Binders    3.564         3      0.80
# 8533  Central        Furniture       Chairs  389.970         3      0.00
#
#        Profit
# 218   22.6782
# 568    9.3312
# 591    3.6288
# 845    6.8714
# 925    5.4432
# 935    5.4432
# 1037  13.7340
# 1103  -4.9878
# 1143   3.1104
# 1186  12.4416
# 1479  12.4416
# 1710   6.5670
# 1741   7.2576
# 2044   5.4432
# 2128   7.2576
# 2198   5.4432
# 2251   9.3312
# 2803   5.7780
# 2807   6.2208
# 2836   9.3312
# 2887   6.2208
# 3025   8.0730
# 3127  23.0864
# 3405 -12.0588
# 3412   3.1752
# 3842   2.2450
# 3940   6.2608
# 4089   9.9360
# 4117   9.3312
# 4311   9.3312
# 4498   6.2208
# 5067   6.2060
# 5079 -29.6058
# 5098  -8.3524
# 5227 -44.1960
# 5299   8.6940
# 5329  11.7488
# 5372   5.4432
# 5405  15.2208
# 5493  19.8720
# 5982   6.3504
# 6245   6.4206
# 6391   6.7252
# 6409  16.1838
# 6774  18.6624
# 7123   4.4088
# 7708   0.5097
# 8219   1.7248
# 8457  -6.2370
# 8533  35.0973

# %%
#Drop duplicated rows
df.drop_duplicates(inplace=True)
#Find no. of rows and columns
df.shape
# Out:
# (9944, 12)

# %%
#Calculate Profit Margin
df['Profit Margin %']=(df.Profit/df.Sales)*100
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State
# 0    Second Class   Consumer  United States        Henderson    Kentucky  \
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount
# 0  South        Furniture    Bookcases  261.9600         2      0.00  \
# 1  South        Furniture       Chairs  731.9400         3      0.00
# 2   West  Office Supplies       Labels   14.6200         2      0.00
# 3  South        Furniture       Tables  957.5775         5      0.45
# 4  South  Office Supplies      Storage   22.3680         2      0.20
#
#      Profit  Profit Margin %
# 0   41.9136            16.00
# 1  219.5820            30.00
# 2    6.8714            47.00
# 3 -383.0310           -40.00
# 4    2.5164            11.25

# %%
#Sales Analysis based on Region
df.groupby("Region")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
#Profit Analysis based on Region
df.groupby("Region")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Region")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
df.groupby("Segment")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
df.groupby("Segment")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
df.groupby("Category")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
df.groupby("Category")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
df.groupby("Category")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Category")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
df.groupby("State")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
df.groupby("State")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
category_analysis = pd.DataFrame(df.groupby(['Category'])[['Sales', 'Profit', 'Quantity']].sum())
category_analysis
# Out:
#                        Sales       Profit  Quantity
# Category
# Furniture        740568.6663   18484.9459      8010
# Office Supplies  718256.0700  122196.0726     22786
# Technology       835774.6410  145416.5394      6932

# %% [markdown]
# Exploratory Data Analysis

# %%
#Which Category is Best Selling and Most Profitable?
# Group sales, profit and quantity by category
category_analysis = pd.DataFrame(df.groupby(['Category'])[['Sales', 'Profit', 'Quantity']].sum())
category_analysis
# Out:
#                        Sales       Profit  Quantity
# Category
# Furniture        740568.6663   18484.9459      8010
# Office Supplies  718256.0700  122196.0726     22786
# Technology       835774.6410  145416.5394      6932

# %%
# Set for grouped plots - figure with a 2x2 grid of Axes
sns.set_theme(style="whitegrid")
figure, axis = plt.subplots(1, 3, figsize=(8, 5))
# Plot barplots
cat1 = sns.barplot(x = category_analysis.index, y = category_analysis.Sales, ax=axis[0])
cat2 = sns.barplot(x = category_analysis.index, y = category_analysis.Profit, ax=axis[1])
cat3 = sns.barplot(x = category_analysis.index, y = category_analysis.Quantity, ax=axis[2])
# Set titles
cat1.set(title = 'Sales')
cat2.set(title = 'Profit')
cat3.set(title = 'Quantity')
# Rotate axis for x-axis
plt.setp(cat1.get_xticklabels(), rotation = 'vertical', size = 9)
plt.setp(cat2.get_xticklabels(), rotation = 'vertical', size = 9)
plt.setp(cat3.get_xticklabels(), rotation = 'vertical', size = 9)
# Set spacing between subplots
figure.tight_layout()

# %%
#What are the Best Selling and Most Profitable Sub-Category?
# Group by sub-category
subcat_analysis = pd.DataFrame(df.groupby(['Sub-Category'])[['Sales', 'Profit']].sum())
# Sort by descending order according to sales
subcat_sales = pd.DataFrame(subcat_analysis.sort_values('Sales', ascending = False))
subcat_sales
# Out:
#                     Sales      Profit
# Sub-Category
# Phones        329704.6780  44493.0524
# Chairs        327777.7610  26567.1278
# Storage       223808.4400  21287.1788
# Tables        206965.5320 -17725.4811
# Binders       203328.8590  30205.2603
# Machines      189238.6310   3384.7569
# Accessories   167303.3020  41920.9052
# Copiers       149528.0300  55617.8249
# Bookcases     114166.9293  -3398.7542
# Appliances    107532.1610  18138.0054
# Furnishings    91658.4440  13042.0534
# Paper          77960.8940  33830.0381
# Supplies       46673.5380  -1189.0995
# Art            27065.7320   6511.8388
# Envelopes      16476.4020   6964.1767
# Labels         12385.7640   5499.1558
# Fasteners       3024.2800    949.5182

# %%
# Sort by descending order according to profit
subcat_profit = pd.DataFrame(subcat_analysis.sort_values('Profit', ascending = False))
subcat_profit
# Out:
#                     Sales      Profit
# Sub-Category
# Copiers       149528.0300  55617.8249
# Phones        329704.6780  44493.0524
# Accessories   167303.3020  41920.9052
# Paper          77960.8940  33830.0381
# Binders       203328.8590  30205.2603
# Chairs        327777.7610  26567.1278
# Storage       223808.4400  21287.1788
# Appliances    107532.1610  18138.0054
# Furnishings    91658.4440  13042.0534
# Envelopes      16476.4020   6964.1767
# Art            27065.7320   6511.8388
# Labels         12385.7640   5499.1558
# Machines      189238.6310   3384.7569
# Fasteners       3024.2800    949.5182
# Supplies       46673.5380  -1189.0995
# Bookcases     114166.9293  -3398.7542
# Tables        206965.5320 -17725.4811

# %%
#Bar Plots
sns.set_theme(style="whitegrid")
# Set for grouped plots - figure with a 1x2 grid of Axes
figure, axis = plt.subplots(1, 2, figsize=(12, 6))
# Plot Bar Plot for Best Selling Sub-Category
subcat1 = sns.barplot(data = subcat_sales, x = subcat_sales.index, y = subcat_sales.Sales, ax=axis[0])
subcat1.set(title="Best Selling Sub-Category")
subcat1.set_xticklabels(subcat1.get_xticklabels(),rotation = "vertical", size = 10)
# Plot Bar Plot for Most Profitable Sub-Category
subcat2 = sns.barplot(data = subcat_profit, x = subcat_profit.index, y = subcat_profit.Profit, ax=axis[1])
subcat2.set(title = "Most Profitable Sub-Category")
subcat2.set_xticklabels(subcat2.get_xticklabels(),rotation = "vertical", size = 10)
# Set spacing between subplots
figure.tight_layout()
plt.show()

# %%
#Which is the Top Selling Sub-Category?
subcat_quantity = pd.DataFrame(df.groupby(['Sub-Category'])[['Quantity']].sum().sort_values('Quantity',ascending=False))
subcat_quantity
# Out:
#               Quantity
# Sub-Category
# Binders           5961
# Paper             5100
# Furnishings       3555
# Phones            3286
# Storage           3156
# Art               2986
# Accessories       2972
# Chairs            2351
# Appliances        1729
# Labels            1387
# Tables            1241
# Fasteners          914
# Envelopes          906
# Bookcases          863
# Supplies           647
# Machines           440
# Copiers            234

# %%
#Bar Plot for Top Selling Sub-Category
sns.set_theme(style="whitegrid")
sns.barplot(data = subcat_quantity, y = subcat_quantity.index, x = subcat_quantity.Quantity, palette = "muted")
plt.title("Top Selling Sub-Category")
plt.show()

# %%
#Which Customer Segment is Most Profitable?
segment_analysis = pd.DataFrame(df.groupby(['Segment'])[['Profit']].sum())
segment_analysis
# Out:
#                   Profit
# Segment
# Consumer     133939.5218
# Corporate     91911.1606
# Home Office   60246.8755

# %%
#Bar Plot
sns.set_theme(style="whitegrid")
sns.barplot(data = segment_analysis, x = segment_analysis.index, y = segment_analysis.Profit, palette = "rocket")
plt.title("Customer Segment Profitability")
plt.show()

# %%
#Which Region is the Most Profitable?
region_analysis = pd.DataFrame(df.groupby(['Region'])['Profit'].sum().reset_index())
region_analysis
# Out:
#     Region       Profit
# 0  Central   39662.0474
# 1     East   91471.0909
# 2    South   46749.4303
# 3     West  108214.9893

# %%
#Pie Chart
explode = [0, 0, 0, 0.1]
plt.pie(region_analysis.Profit, labels = region_analysis.Region, startangle = 90, autopct = "%1.0f%%", explode = explode, shadow = True)
plt.title("Most Profitable by Region")
plt.show()
